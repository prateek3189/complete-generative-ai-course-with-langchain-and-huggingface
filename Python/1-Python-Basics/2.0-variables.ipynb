# %%
a=100

# %%
## Declaring and ssigning values to variables
age = 37
height = 5.6
name = "Prateek"
is_employee = True

print("Age:", age)
print("Height:", height)
print("Name:", name)
print("Is Employee:", is_employee)
# Out:
# Age: 37
# Height: 5.6
# Name: Prateek
# Is Employee: True

# %%
## Naming Conventions
## Variable name should be descriptive and should also start with a _ or letter and it can contain letters, numbers and underscore
## Variables names are case sensitive 

first_name = "John"
last_name = "Doe"

# %%
age_str = str(35)
print(age_str)
print(type(age_str))
# Out:
# 35
# <class 'str'>

# %%
height = 5.6
int(height)
# Out:
# 5

# %%
height_float = float(5)
print(height_float)
# Out:
# 5.0

# %%
## Python allows a type of variable to change as the program executes
var = 10
print(var, type(var))

var = "Hello"
print(var, type(var))
# Out:
# 10 <class 'int'>
# Hello <class 'str'>

# %%
## input 
age = input("Enter your age: ")
print("You entered:", age)
print("Type of age:", type(age))
# Out:
# You entered: 37
# Type of age: <class 'str'>

# %%
## Calculator
a = input("Enter first number: ")
b = input("Enter second number: ")
sum = int(a) + int(b)
print("The sum of", a, "and", b, "is:", sum)
# Out:
# The sum of 10 and 20 is: 30
