# %%
## Integers
a = 5
print(a, type(a))
# Out:
# 5 <class 'int'>

# %%
## Floating
height = 5.6;
print(height, type(height))
# Out:
# 5.6 <class 'float'>

# %%
## String
name = "Prateek"
print(name, type(name))
# Out:
# Prateek <class 'str'>

# %%
## Boolean
is_adult = True
print(is_adult, type(is_adult))
# Out:
# True <class 'bool'>

# %%
str = "Hello"
