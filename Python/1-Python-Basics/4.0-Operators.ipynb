# %% [markdown]
# ## Arithmatic Operations

# %%
## Addition
a = 10
b = 5
result = a + b
print(result)
# Out:
# 15

# %%
## Subtraction
a = 10
b = 5
result = a - b
print(result)
# Out:
# 5

# %%
## Multiplication
a = 10
b = 5
result = a * b
print(result)
# Out:
# 50

# %%
a = 10
b = 5
result = a / b
print(result)
# Out:
# 2.0

# %%
a = 10
b = 5
result = a // b
print(result)
# Out:
# 2

# %%
a = 10
b = 6
result = a % b
print(result)
# Out:
# 4

# %%
a = 10
b = 5
result = a**b
print(result)
# Out:
# 100000

# %% [markdown]
# ## Comparision Operators

# %%
## Comparision Operators
a = 10
b = 10
a == b
# Out:
# True

# %%
str1 = "Hello"
str2 = "hello"
str1 == str2
# Out:
# False

# %%
a = 10
b = 5
a!= b
# Out:
# True

# %%
print(10>20)
print(20<40)
# Out:
# False
# True

# %%
num1 = 44
num2 = 45
print(num1>=num2)
print(num1<=num2)
# Out:
# False
# True

# %% [markdown]
# ## Logical Operators

# %%
## AND AND OR Operators
if num1 > 40 and num2 > 40:
     print("Both numbers are greater than 40")
if num1 > 40 or num2 > 50:
     print("One number is not greater than 40")
# Out:
# Both numbers are greater than 40
# One number is not greater than 40

# %%
## Not Operator
x = True
print(not x)
# Out:
# False
