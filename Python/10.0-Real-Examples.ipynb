# %% [markdown]
# ### Real Examples

# %%
todos = ["Buy groceries", "Clean the house", "Pay bills", "Finish project"]

## Add Task
todos.append("Read a book")

## Remove the task
todos.remove("Clean the house")

if "Pay bills" in todos:
    todos.remove("Pay bills")

print(todos)
# Out:
# ['Buy groceries', 'Finish project', 'Read a book']
