# %% [markdown]
# ## Import Modules

# %%
import math

math.sqrt(16)
# Out:
# 4.0

# %%
from math import sqrt, pi
result = sqrt(16)  # Output: 4.0
print(result)
print(pi)
# Out:
# 4.0
# 3.141592653589793

# %%
import numpy as np

arr = np.array([1, 2, 3, 4, 5])
print(arr)
# Out:
# [1 2 3 4 5]

# %%
from math import *
sqrt(25)
# Out:
# 5.0

# %%
from package.calculator import addition, subtraction, multiplication, division

add_result = addition(10, 5)
subtraction_result = subtraction(10, 5)
multiplication_result = multiplication(10, 5)
division_result = division(10, 5)

print("Addition:", add_result)
print("Subtraction:", subtraction_result)
print("Multiplication:", multiplication_result)
print("Division:", division_result)
# Out:
# Addition: 15
# Subtraction: 5
# Multiplication: 50
# Division: 2.0
