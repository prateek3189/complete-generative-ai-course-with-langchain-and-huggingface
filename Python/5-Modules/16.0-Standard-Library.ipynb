# %% [markdown]
# # Standard Library

# %%
import array
arr = array.array("i", [1,2,3,4])
print(arr)
# Out:
# array('i', [1, 2, 3, 4])

# %%
import math

print(math.pi)
print(math.sqrt(16))
# Out:
# 3.141592653589793
# 4.0

# %%
import random
print(random.randint(1, 10))
print(random.choice(["apple", "cherry"]))
# Out:
# 3
# cherry

# %%
### File and Directory Access
import os
print(os.getcwd())
# Out:
# /Users/prateek.magarde/Documents/Taxila/AI Engineering - 8 Phases/complete-generative-ai-course-with-langchain-and-huggingface/Python/5-Modules

# %%
os.mkdir("test_dir")

# %%
## High level operations
import shutil
shutil.copy("source.txt", "destination.txt")
# Out:
# 'destination.txt'

# %%
## Data serialization
import json
data = {"name": "Prateek", "age": 37}

json_str = json.dumps(data)
print(json_str)

print(json.loads(json_str))
# Out:
# {"name": "Prateek", "age": 37}
# {'name': 'Prateek', 'age': 37}

# %%
## csv
import csv
with open("example.csv", mode='w', newline="") as file:
  writer = csv.writer(file)
  writer.writerow(["name", "age"])
  writer.writerow(["Prateek", 37])

with open("example.csv", mode="r") as file:
  reader = csv.reader(file)
  for row in reader:
    print(row)
# Out:
# ['name', 'age']
# ['Prateek', '37']

# %%
from datetime import datetime, timedelta

now = datetime.now()
print(now)

yesterday = now - timedelta(days=1)
print(yesterday)
# Out:
# 2026-08-15 22:35:30.176093
# 2026-08-14 22:35:30.176093

# %%
import time 
print(time.time())
time.sleep(2)
print(time.time())
# Out:
# 1786813574.6451461
# 1786813576.6517062

# %%
## Regular Expression
import re

pattern = r'\d+'
text = "There are 123 apples"
match = re.search(pattern, text)
print(match.group())
# Out:
# 123
